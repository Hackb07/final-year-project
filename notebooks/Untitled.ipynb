# %%
from ultralytics import YOLO

# %%
from ultralytics import YOLO

model = YOLO("yolo11n.pt")

results = model.train(
    data=r"D:\final-year\mvp\data\data.yaml",
    epochs=100,
    imgsz=640,
    batch=16
)
# Out:
# Ultralytics 8.4.120  Python-3.10.20 torch-2.13.0+cu126 CUDA:0 (NVIDIA GeForce RTX 3050 6GB Laptop GPU, 6144MiB)
# ...
